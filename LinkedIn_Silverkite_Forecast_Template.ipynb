# %% [markdown]
# <a href="https://colab.research.google.com/github/mrcruz117/linkedin-silverkite-forecast-templates/blob/main/LinkedIn_Silverkite_Forecast_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Silverkite Forecast

# %%
#change directory
# %cd /content/drive/MyDrive/Time Series Forecasting Product
# Out:
# /content/drive/MyDrive/Time Series Forecasting Product

# %%
# !pip install greykite

# %%
#libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from greykite.framework.templates.autogen.forecast_config import *
from greykite.framework.templates.forecaster import Forecaster
from greykite.framework.templates.model_templates import ModelTemplateEnum
from greykite.common.features.timeseries_features import *
from greykite.common.evaluation import EvaluationMetricEnum
from greykite.framework.utils.result_summary import summarize_grid_search_results
from plotly.offline import iplot

# %%
#load the data
#YYYY-MM-DD
df = pd.read_csv('nyc_data.csv')
future_df = pd.read_csv('future.csv')
future_df.head()
df.head()
# Out:
#        Date      Demand  Easter  Thanksgiving  Christmas  Temperature  \
# 0  1/1/2015  720.000885       0             0          0         3.68
# 1  1/2/2015  581.276773       0             0          0         4.73
# 2  1/3/2015  754.117039       0             0          0         7.23
# 3  1/4/2015  622.252774       0             0          0        10.96
# 4  1/5/2015  785.373319       0             0          0         6.92
#
#    Marketing
# 0     41.305
# 1    131.574
# 2    162.700
# 3    160.281
# 4     51.077

# %%
# merge dfs

df = pd.concat([df, future_df])
df = df.reset_index(drop=True)
df.tail()
# Out:
#            Date  Demand  Easter  Thanksgiving  Christmas  Temperature  \
# 2218  1/27/2021     NaN       0             0          0         3.33
# 2219  1/28/2021     NaN       0             0          0         1.67
# 2220  1/29/2021     NaN       0             0          0        -2.78
# 2221  1/30/2021     NaN       0             0          0         1.11
# 2222  1/31/2021     NaN       0             0          0         4.44
#
#       Marketing
# 2218     39.664
# 2219    195.314
# 2220    235.894
# 2221    152.752
# 2222    158.620

# %%
#Rename variable
df = df.rename(columns = {'Demand': 'y'})
df.head(0)
# Out:
# Empty DataFrame
# Columns: [Date, y, Easter, Thanksgiving, Christmas, Temperature, Marketing]
# Index: []

# %% [markdown]
# ## Silverkite Prep

# %%
# Load the tuned parameters
parameters = pd.read_csv("Forecasting Product/best_params_silverkite.csv",
                         index_col = 0)
parameters
# Out:
#                                     [('estimator__growth_term', 'quadratic'), ('estimator__fit_algorithm_dict', {'fit_algorithm': 'linear'})]
# mean_test_RMSE                                                                    47.4
# param_estimator__fit_algorithm_dict                        {'fit_algorithm': 'linear'}
# param_estimator__growth_term                                                 quadratic

# %%
# isolate tuned params
growth_term_param = parameters.loc["param_estimator__growth_term"][0]
fit_algorithm_param = parameters.loc["param_estimator__fit_algorithm_dict"][0]

# %%
# time series name specifications
metadata = MetadataParam(
    time_col="Date",
    value_col="y",
    freq="D",
    train_end_date=pd.to_datetime("2020-12-31"),
)
metadata
# Out:
# MetadataParam(anomaly_info=None, date_format=None, freq='D', time_col='Date', train_end_date=Timestamp('2020-12-31 00:00:00'), value_col='y')

# %%
# growth term
growth =  dict(
    growth_term=growth_term_param,
)
growth
# Out:
# {'growth_term': 'quadratic'}

# %%
# seasonalities
seasonality = dict(
    yearly_seasonality="auto",
    quarterly_seasonality="auto",
    monthly_seasonality="auto",
    weekly_seasonality="auto",
    daily_seasonality="auto",
)
seasonality
# Out:
# {'yearly_seasonality': 'auto',
#  'quarterly_seasonality': 'auto',
#  'monthly_seasonality': 'auto',
#  'weekly_seasonality': 'auto',
#  'daily_seasonality': 'auto'}

# %%
# holidays modeling
get_available_holiday_lookup_countries(["US"])
get_available_holidays_across_countries(countries=["US"],
                                        year_start=2015,
                                        year_end=2021)
# Out:
# ['Christmas Day',
#  'Christmas Day (Observed)',
#  'Columbus Day',
#  'Halloween',
#  'Independence Day',
#  'Independence Day (Observed)',
#  'Juneteenth National Independence Day',
#  'Juneteenth National Independence Day (Observed)',
#  'Labor Day',
#  'Martin Luther King Jr. Day',
#  'Memorial Day',
#  "New Year's Day",
#  "New Year's Day (Observed)",
#  'Thanksgiving',
#  'Veterans Day',
#  'Veterans Day (Observed)',
#  "Washington's Birthday"]

# %%
# specifying events
events = dict(
    holidays_to_model_separately = ["New Year's Day"],
    holiday_pre_num_days = 2,
    holiday_post_num_days = 2,
    holiday_pre_post_num_dict = {"New Year's Day":(3,1)},
    # adding one thats not there
    # daily_event_df_dict = {"elections": pd.DataFrame({
    #     "date": ["2016-11-03", "2020-11-03"],
    #     "event_name": ["elections"] * 2
    # })}
)
events
# Out:
# {'holidays_to_model_separately': ["New Year's Day"],
#  'holiday_pre_num_days': 2,
#  'holiday_post_num_days': 2,
#  'holiday_pre_post_num_dict': {"New Year's Day": (3, 1)}}

# %%
# changepoints: reflects changes in the trend
changepoints = dict(changepoints_dict=dict(method="auto"))

# %%
# regressors
regressors = dict(regressor_cols=["Easter", "Temperature", "Marketing"])
regressors
# Out:
# {'regressor_cols': ['Easter', 'Temperature', 'Marketing']}

# %%
# lagged regressors
lagged_regressors = dict(lagged_regressor_dict={"Temperature": "auto",
                                                 "Easter": "auto",
                                                 "Marketing": "auto"})

# %%
# autoregression: depoendent on the forecasting horizon
autoregression = dict(autoreg_dict= "auto")

# %% [markdown]
# ### Model notes
# - ridge regression model might be better.
# - less risk of overfitting
# - penalizes extreme slopes
#   - makes more sense when we have less data.
#
# - XGBoost
#   - widely applicable
#   - might work as well

# %%
# fitting algos
import yaml
custom = dict(fit_algorithm_dict=yaml.load(fit_algorithm_param,
                                           Loader=yaml.SafeLoader))
custom
# Out:
# {'fit_algorithm_dict': {'fit_algorithm': 'linear'}}

# %% [markdown]
# ## Building the Model

# %%
model_components = ModelComponentsParam(
    growth=growth,
    seasonality=seasonality,
    events=events,
    changepoints=changepoints,
    regressors=regressors,
    lagged_regressors=lagged_regressors,
    autoregression=autoregression,
    custom=custom
)

# %%
# cross-validation
evaluation_period = EvaluationPeriodParam(
    cv_min_train_periods=df.shape[0] - 180 - 31,
    cv_expanding_window=True,
    cv_max_splits=30,
    cv_periods_between_splits=16
)

# %%
# evaluation metric

evaluation_metric = EvaluationMetricParam(
    cv_selection_metric=EvaluationMetricEnum.RootMeanSquaredError.name
)

# %%
# model config
config = ForecastConfig(
    model_template=ModelTemplateEnum.SILVERKITE.name,
    forecast_horizon=31,
    metadata_param=metadata,
    model_components_param=model_components,
    evaluation_period_param=evaluation_period,
    evaluation_metric_param=evaluation_metric,
)

# %%
# fit with tuned params
forecaster = Forecaster()
result = forecaster.run_forecast_config(df=df, config=config)
# Out:
# Fitting 8 folds for each of 1 candidates, totalling 8 fits
# /usr/local/lib/python3.11/dist-packages/greykite/algo/forecast/silverkite/forecast_silverkite.py:3433: UserWarning:
#
# The following Fourier series terms are removed due to collinearity:
# ['sin1_toq_quarterly', 'cos1_toq_quarterly', 'sin2_toq_quarterly', 'cos2_toq_quarterly', 'sin3_toq_quarterly', 'cos3_toq_quarterly', 'cos4_tow_weekly']
#
# /usr/local/lib/python3.11/dist-packages/greykite/algo/forecast/silverkite/forecast_silverkite.py:3433: UserWarning:
#
# The following Fourier series terms are removed due to collinearity:
# ['sin1_toq_quarterly', 'cos1_toq_quarterly', 'sin2_toq_quarterly', 'cos2_toq_quarterly', 'sin3_toq_quarterly', 'cos3_toq_quarterly', 'cos4_tow_weekly']
#
# /usr/local/lib/python3.11/dist-packages/greykite/algo/forecast/silverkite/forecast_silverkite.py:3433: UserWarning:
#
# The following Fourier series terms are removed due to collinearity:
# ['sin1_toq_quarterly', 'cos1_toq_quarterly', 'sin2_toq_quarterly', 'cos2_toq_quarterly', 'sin3_toq_quarterly', 'cos3_toq_quarterly', 'cos4_tow_weekly']
#
# /usr/local/lib/python3.11/dist-packages/greykite/algo/forecast/silverkite/forecast_silverkite.py:3433: UserWarning:
#
# The following Fourier series terms are removed due to collinearity:
# ['sin1_toq_quarterly', 'cos1_toq_quarterly', 'sin2_toq_quarterly', 'cos2_toq_quarterly', 'sin3_toq_quarterly', 'cos3_toq_quarterly', 'cos4_tow_weekly']
#
# /usr/local/lib/python3.11/dist-packages/greykite/algo/forecast/silverkite/forecast_silverkite.py:3433: UserWarning:
#
# The following Fourier series terms are removed due to collinearity:
# ['sin1_toq_quarterly', 'cos1_toq_quarterly', 'sin2_toq_quarterly', 'cos2_toq_quarterly', 'sin3_toq_quarterly', 'cos3_toq_quarterly', 'cos4_tow_weekly']
#
# /usr/local/lib/python3.11/dist-packages/greykite/algo/forecast/silverkite/forecast_silverkite.py:3433: UserWarning:
#
# The following Fourier series terms are removed due to collinearity:
# ['sin1_toq_quarterly', 'cos1_toq_quarterly', 'sin2_toq_quarterly', 'cos2_toq_quarterly', 'sin3_toq_quarterly', 'cos3_toq_quarterly', 'cos4_tow_weekly']
#
# /usr/local/lib/python3.11/dist-packages/greykite/algo/forecast/silverkite/forecast_silverkite.py:3433: UserWarning:
#
# The following Fourier series terms are removed due to collinearity:
# ['sin1_toq_quarterly', 'cos1_toq_quarterly', 'sin2_toq_quarterly', 'cos2_toq_quarterly', 'sin3_toq_quarterly', 'cos3_toq_quarterly', 'cos4_tow_weekly']
#
# /usr/local/lib/python3.11/dist-packages/greykite/algo/forecast/silverkite/forecast_silverkite.py:3433: UserWarning:
#
# The following Fourier series terms are removed due to collinearity:
# ['sin1_toq_quarterly', 'cos1_toq_quarterly', 'sin2_toq_quarterly', 'cos2_toq_quarterly', 'sin3_toq_quarterly', 'cos3_toq_quarterly', 'cos4_tow_weekly']
#
# /usr/local/lib/python3.11/dist-packages/greykite/algo/forecast/silverkite/forecast_silverkite.py:3433: UserWarning:
#
# The following Fourier series terms are removed due to collinearity:
# ['sin1_toq_quarterly', 'cos1_toq_quarterly', 'sin2_toq_quarterly', 'cos2_toq_quarterly', 'sin3_toq_quarterly', 'cos3_toq_quarterly', 'cos4_tow_weekly']
#
# /usr/local/lib/python3.11/dist-packages/greykite/algo/forecast/silverkite/forecast_silverkite.py:3433: UserWarning:
#
# The following Fourier series terms are removed due to collinearity:
# ['sin1_toq_quarterly', 'cos1_toq_quarterly', 'sin2_toq_quarterly', 'cos2_toq_quarterly', 'sin3_toq_quarterly', 'cos3_toq_quarterly', 'cos4_tow_weekly']

# %%
# visualization

fig = result.backtest.plot()
iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="809fefa1-dd6d-4526-adbb-7fbcc8eae905" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("809fefa1-dd6d-4526-adbb-7fbcc8eae905")) {                    Plotly.newPlot(                        "809fefa1-dd6d-4526-adbb-7fbcc8eae905",                        [{"line":{"color":"rgba(250, 43, 20, 0.7)"},"marker":{"color":"rgba(250, 43, 20, 0.7)","size":2.0},"mode":"lines+markers","name":"Actual","opacity":1.0,"x":["2015-01-01T00:00:00","2015-01-02T00:00:00","2015-01-03T00:00:00","2015-01-04T00:00:00","2015-01-05T00:00:00","2015-01-06T00:00:00","2015-01-07T00:00:00","2015-01-08T00:00:00","2015-01-09T00:00:00","2015-01-10T00:00:00","2015-01-11T00:00:00","2015-01-12T00:00:00","2015-01-13T00:00:00","2015-01-14T00:00:00","2015-01-15T00:00:00","2015-01-16T00:00:00","2015-01-17T00:00:00","2015-01-18T00:00:00","2015-01-19T00:00:00","2015-01-20T00:00:00","2015-01-21T00:00:00","2015-01-22T00:00:00","2015-01-23T00:00:00","2015-01-24T00:00:00","2015-01-25T00:00:00","2015-01-26T00:00:00","2015-01-27T00:00:00","2015-01-28T00:00:00","2015-01-29T00:00:00","2015-01-30T00:00:00","2015-01-31T00:00:00","2015-02-01T00:00:00","2015-02-02T00:00:00","2015-02-03T00:00:00","2015-02-04T00:00:00","2015-02-05T00:00:00","2015-02-06T00:00:00","2015-02-07T00:00:00","2015-02-08T00:00:00","2015-02-09T00:00:00","2015-02-10T00:00:00","2015-02-11T00:00:00","2015-02-12T00:00:00","2015-02-13T00:00:00","2015-02-14T00:00:00","2015-02-15T00:00:00","2015-02-16T00:00:00","2015-02-17T00:00:00","2015-02-18T00:00:00","2015-02-19T00:00:00","2015-02-20T00:00:00","2015-02-21T00:00:00","2015-02-22T00:00:00","2015-02-23T00:00:00","2015-02-24T00:00:00","2015-02-25T00:00:00","2015-02-26T00:00:00","2015-02-27T00:00:00","2015-02-28T00:00:00","2015-03-01T00:00:00","2015-03-02T00:00:00","2015-03-03T00:00:00","2015-03-04T00:00:00","2015-03-05T00:00:00","2015-03-06T00:00:00","2015-03-07T00:00:00","2015-03-08T00:00:00","2015-03-09T00:00:00","2015-03-10T00:00:00","2015-03-11T00:00:00","2015-03-12T00:00:00","2015-03-13T00:00:00","2015-03-14T00:00:00","2015-03-15T00:00:00","2015-03-16T00:00:00","2015-03-17T00:00:00","2015-03-18T00:00:00","2015-03-19T00:00:00","2015-03-20T00:00:00","2015-03-21T00:00:00","2015-03-22T00:00:00","2015-03-23T00:00:00","2015-03-24T00:00:00","2015-03-25T00:00:00","2015-03-26T00:00:00","2015-03-27T00:00:00","2015-03-28T00:00:00","2015-03-29T00:00:00","2015-03-30T00:00:00","2015-03-31T00:00:00","2015-04-01T00:00:00","2015-04-02T00:00:00","2015-04-03T00:00:00","2015-04-04T00:00:00","2015-04-05T00:00:00","2015-04-06T00:00:00","2015-04-07T00:00:00","2015-04-08T00:00:00","2015-04-09T00:00:00","2015-04-10T00:00:00","2015-04-11T00:00:00","2015-04-12T00:00:00","2015-04-13T00:00:00","2015-04-14T00:00:00","2015-04-15T00:00:00","2015-04-16T00:00:00","2015-04-17T00:00:00","2015-04-18T00:00:00","2015-04-19T00:00:00","2015-04-20T00:00:00","2015-04-21T00:00:00","2015-04-22T00:00:00","2015-04-23T00:00:00","2015-04-24T00:00:00","2015-04-25T00:00:00","2015-04-26T00:00:00","2015-04-27T00:00:00","2015-04-28T00:00:00","2015-04-29T00:00:00","2015-04-30T00:00:00","2015-05-01T00:00:00","2015-05-02T00:00:00","2015-05-03T00:00:00","2015-05-04T00:00:00","2015-05-05T00:00:00","2015-05-06T00:00:00","2015-05-07T00:00:00","2015-05-08T00:00:00","2015-05-09T00:00:00","2015-05-10T00:00:00","2015-05-11T00:00:00","2015-05-12T00:00:00","2015-05-13T00:00:00","2015-05-14T00:00:00","2015-05-15T00:00:00","2015-05-16T00:00:00","2015-05-17T00:00:00","2015-05-18T00:00:00","2015-05-19T00:00:00","2015-05-20T00:00:00","2015-05-21T00:00:00","2015-05-22T00:00:00","2015-05-23T00:00:00","2015-05-24T00:00:00","2015-05-25T00:00:00","2015-05-26T00:00:00","2015-05-27T00:00:00","2015-05-28T00:00:00","2015-05-29T00:00:00","2 ...

# %%
# look at summary
result.model[-1].summary()
# Out:
# ============================ Forecast Model Summary ============================
#
# Number of observations: 2192,   Number of features: 181
# Method: Ordinary least squares
# Number of nonzero features: 181
#
# Residuals:
#          Min           1Q       Median           3Q          Max
#       -163.1       -32.35      -0.4705        30.28        236.6
#
#             Pred_col Estimate Std. Err   t value Pr(>|t|) sig. code              95%CI
#            Intercept    67.11    3.006     22.32   <2e-16       ***      (61.21, 73.0)
# events_New Years Day   -11.49    22.78   -0.5043    0.614              (-56.15, 33.18)
#  events_N...rs Day-1   -32.34    22.97    -1.408    0.159               (-77.39, 12.7)
#  events_N...rs Day-2   -3.502    22.88   -0.1531    0.878              (-48.37, 41.37)
#  events_N...rs Day-3   -35.43    22.74    -1.558    0.119              (-80.03, 9.171)
#  events_N...rs Day+1    4.535    22.63    0.2004    0.841              (-39.85, 48.92)
#         events_Other   -1.448    3.401   -0.4258    0.670              (-8.118, 5.222)
#       events_Other-1   -4.077    3.387    -1.204    0.229              (-10.72, 2.565)
#       events_Other-2   -2.151    3.333   -0.6455    0.519              (-8.687, 4.385)
#       events_Other+1   -4.105    3.367    -1.219    0.223              (-10.71, 2.499)
#       events_Other+2    2.824     3.37    0.8382    0.402              (-3.784, 9.432)
#        str_dow_2-Tue   -18.37    4.286    -4.286 1.90e-05       ***   (-26.78, -9.965)
#        str_dow_3-Wed    49.34    4.135     11.93   <2e-16       ***     (41.23, 57.45)
#        str_dow_4-Thu    18.53    4.005     4.626 3.95e-06       ***     (10.67, 26.38)
#        str_dow_5-Fri   -30.01    3.973    -7.554 6.31e-14       ***    (-37.8, -22.22)
#        str_dow_6-Sat    21.63    4.207     5.141 2.99e-07       ***     (13.38, 29.88)
#        str_dow_7-Sun    6.606    4.599     1.437    0.151              (-2.412, 15.62)
#               Easter   -9.669    21.54   -0.4489    0.654              (-51.92, 32.58)
#          Temperature   -14.33    13.81    -1.038    0.299              (-41.41, 12.75)
#            Marketing    3.619    5.493    0.6589    0.510              (-7.153, 14.39)
#                  ct2    437.5    227.3     1.924    0.054         .    (-8.333, 883.2)
#       is_weekend:ct2   -24.67    210.7   -0.1171    0.907              (-437.8, 388.5)
#    str_dow_2-Tue:ct2   -546.2    446.0    -1.225    0.221             (-1421.0, 328.4)
#    str_dow_3-Wed:ct2    614.3    339.2     1.811    0.070         .   (-50.97, 1279.0)
#    str_dow_4-Thu:ct2   -671.6    367.3    -1.828    0.068         .   (-1392.0, 48.78)
#    str_dow_5-Fri:ct2   -23.81    365.4  -0.06518    0.948              (-740.3, 692.7)
#    str_dow_6-Sat:ct2    280.2    336.6    0.8323    0.405              (-380.0, 940.4)
#    str_dow_7-Sun:ct2   -304.6    385.0    -0.791    0.429             (-1060.0, 450.5)
#    cp0_2016_01_26_00    77.34    125.5    0.6165    0.538              (-168.7, 323.4)
#  is_weeke...01_26_00     50.9    116.3    0.4377    0.662              (-177.2, 279.0)
#  str_dow_...01_26_00    208.0    246.0    0.8452    0.398              (-274.6, 690.5)
#  str_dow_...01_26_00   -219.6    187.0    -1.174    0.241              (-586.3, 147.2)
#  str_dow_...01_26_00    375.2    202.7     1.851    0.064         .    (-22.26, 772.7)
#  str_dow_...01_26_00    46.29    201.7    0.2295    0.818              (-349.2, 441.8)
#  str_dow_...01_26_00   -85.18    185.9   -0.4582    0.647              (-449.8, 279.4)
#  str_dow_...01_26_00    136.0    212.6    0.6398    0.522              (-280.9, 553.0)
#    cp1_2017_09_03_00  -1078.0    197.8    -5.452 5.57e-08       ***  (-1466.0, -690.3)
#  is_weeke...09_03_00    22.05    178.0    0.1239    0.901              (-327.0, 371.1)
#  str_dow_...09_03_00    119.9    374.9    0.3198    0.749              (-615.2, 855.0)
#  str_dow_...09_03_00   -596.8    284.8    -2.096    0.036         *  (-1155.0, -38.33)
#  str_dow_...09_03_00    211.2    309.2    0.6829    0.495              (-395.3, 817.6)
#  str_dow_...09_03_00   -105.0    308.0   -0.3408    0.733              (-709.1, 499.1)
#  str_dow_...09_03_00   -142.3    284.2   -0.5007    0.617              (-699.6, 415.1)
#  str_dow_...09_03_00    164.2    325.1    0.5052    0.613              (-473.3, 801.7)
#    cp2_2017_11_07_00   2201.0    285.1     7.722 1.77e-14       ***   (1642.0, 2760.0)
#  is_weeke...11_07_00    223.8    246.5     0.908    0.364              (-259.6, 707.1)
#  str_dow_...11_07_00    178.2    518.7    0.3436    0.731             (-839.0, 1195.0)
#  str_dow_...11_07_00    675.3    394.4     1.712    0.087         .    (-98.2, 1449.0)
#  str_dow_...11_07_00    332.1    428.5    0.7751    0.438             (-508.3, 1173.0)
#  str_dow_...11_07_00    65.66    426.7    0.1539    0.878              (-771.2, 902.5)
#  str_dow_...11_07_00    339.6    393.6    0.8629    0.388             (-432.3, 1111.0)
#  str_dow_...11_07_00   -115.5    450.3   -0.2566    0.798              (-998.7, 767.6)
#    cp3_2018_02_24_00  -1481.0    156.9    -9.437   <2e-16       *** (-1788.0, -1173.0)
#  is_weeke...02_24_00   -218.8    134.0    -1.632    0.103               (-481.6, 44.1)
#  str_dow_...02_24_00   -141.2    282.6   -0.4997    0.617              (-695.3, 412.9)
#  str_dow_...02_24_00   -192.8    215.0    -0.897    0.370              (-614.4, 228.7)
#  str_dow_...02_24_00   -433.3    233.4    -1.856    0.064         .    (-891.0, 24.49)
#  str_dow_...02_24_00    130.9    232.2    0.5637    0.573              (-324.4, 586.2)
#  str_dow_...02_24_00   -364.4    214.0    -1.702    0.089         .    (-784.1, 55.41)
#  str_dow_...02_24_00    145.2    245.2    0.5924    0.554              (-335.6, 626.1)
#    cp4_2018_09_29_00    570.4    266.9     2.137    0.033         *    (46.91, 1094.0)
#  is_weeke...09_29_00    166.0    236.1    0.7032    0.482              (-296.9, 629.0)
#  str_dow_...09_29_00   -491.0    500.0   -0.9821    0.326             (-1471.0, 489.5)
#  str_dow_...09_29_00   -271.1    380.0   -0.7134    0.476             (-1016.0, 474.1)
#  str_dow_...09_29_00    228.1    412.0    0.5536    0.580             (-579.9, 1036.0)
#  str_dow_...09_29_00   -543.7    409.0    -1.329    0.184             (-1346.0, 258.4)
#  str_dow_...09_29_00    730.6    377.4     1.936    0.053         .   (-9.628, 1471.0)
#  str_dow_...09_29_00   -563.7    432.3    -1.304    0.192             (-1411.0, 284.2)
#    cp5_2018_11_11_00    298.6    324.1    0.9212    0.357              (-337.1, 934.2)
#  is_weeke...11_11_00   -110.8    279.2   -0.3966    0.692              (-658.4, 436.9)
#  str_dow_...11_11_00    380.1    590.7    0.6435    0.520             (-778.2, 1538.0)
#  str_dow_...11_11_00    465.2    449.3     1.035    0.301             (-416.1, 1346.0)
#  str_dow_...11_11_00    18.12    487.5   0.03717    0.970              (-937.8, 974.1)
#  str_dow_...11_11_00    514.3    483.9     1.063    0.288             (-434.7, 1463.0)
#  str_dow_...11_11_00   -522.9    446.0    -1.172    0.241             (-1398.0, 351.8)
#  str_dow_...11_11_00    411.5    510.6    0.8059    0.420             (-589.9, 1413.0)
#    cp6_2019_02_06_00   -842.3    120.7    -6.982 3.92e-12       ***  (-1079.0, -605.7)
#  is_weeke...02_06_00    66.64    99.87    0.6673    0.505              (-129.2, 262.5)
#  str_dow_...02_06_00    164.1    210.7    0.7786    0.436              (-249.2, 577.3)
#  str_dow_...02_06_00   -283.6    160.3    -1.769    0.077         .    (-598.1, 30.81)
#  str_dow_...02_06_00   -31.21    174.1   -0.1793    0.858              (-372.7, 310.3)
#  str_dow_...02_06_00   -13.35    172.8  -0.07723    0.938              (-352.3, 325.6)
#  str_dow_...02_06_00   -164.0    159.3     -1.03    0.303              (-476.4, 148.3)
#  str_dow_...02_06_00    230.4    182.4     1.264    0.207              (-127.2, 588.1)
#    cp7_2019_12_07_00   -535.4    68.25    -7.844 6.94e-15       ***   (-669.2, -401.5)
#  is_weeke...12_07_00     11.3    55.22    0.2047    0.838              (-96.99, 119.6)
#  str_dow_...12_07_00     1.63    116.5     0.014    0.989              (-226.8, 230.0)
#  str_dow_...12_07_00   -194.9    88.67    -2.198    0.028         *   (-368.8, -21.02)
#  str_dow_...12_07_00   -11.66    96.27   -0.1211    0.904              (-200.4, 177.1)
#  str_dow_...12_07_00   -92.51    95.55   -0.9682    0.333              (-279.9, 94.87)
#  str_dow_...12_07_00    71.57    87.97    0.8136    0.416              (-100.9, 244.1)
#  str_dow_...12_07_00   -60.08    100.6   -0.5971    0.550              (-257.4, 137.2)
#    cp8_2020_02_10_00    365.0    56.59      6.45 1.39e-10       ***     (254.0, 475.9)
#  is_weeke...02_10_00   -16.38    46.04   -0.3557    0.722              (-106.7, 73.91)
#  str_dow_...02_10_00   -8.519    96.75  -0.08805    0.930              (-198.3, 181.2)
#  str_dow_...02_10_00    102.8    73.65     1.396    0.163              (-41.65, 247.2)
#  str_dow_...02_10_00     76.3    80.01    0.9537    0.340               (-80.6, 233.2)
#  str_dow_...02_10_00    84.42    79.58     1.061    0.289              (-71.64, 240.5)
#  str_dow_...02_10_00    -65.2    73.16   -0.8912    0.373              (-208.7, 78.28)
#  str_dow_...02_10_00    48.62    83.72    0.5808    0.561              (-115.6, 212.8)
#  ct2:sin1_tow_weekly   -40.42    212.0   -0.1906    0.849              (-456.2, 375.4)
#  ct2:cos1_tow_weekly    552.1    410.3     1.346    0.179             (-252.5, 1357.0)
#  ct2:sin2_tow_weekly    98.14    256.5    0.3825    0.702              (-405.0, 601.3)
#  ct2:cos2_tow_weekly    52.91    361.2    0.1465    0.884              (-655.5, 761.3)
#  cp0_2016...w_weekly    68.42    116.8    0.5856    0.558              (-160.7, 297.5)
#  cp0_2016...w_weekly   -221.3    226.2   -0.9783    0.328              (-665.0, 222.3)
#  cp0_2016...w_weekly    -32.6    141.7   -0.2301    0.818              (-310.4, 245.2)
#  cp0_2016...w_weekly    72.61    199.3    0.3644    0.716              (-318.2, 463.4)
#  cp1_2017...w_weekly   -141.6    179.0   -0.7911    0.429              (-492.8, 209.5)
#  cp1_2017...w_weekly   -223.9    346.6    -0.646    0.518              (-903.6, 455.8)
#  cp1_2017...w_weekly   -13.98    215.6  -0.06483    0.948              (-436.8, 408.9)
#  cp1_2017...w_weekly  -0.7444    304.2 -0.002447    0.998              (-597.4, 595.9)
#  cp2_2017...w_weekly    379.6    247.5     1.534    0.125              (-105.8, 864.9)
#  cp2_2017...w_weekly    128.7    479.9    0.2682    0.789             (-812.5, 1070.0)
#  cp2_2017...w_weekly   -1.928    298.7 -0.006456    0.995              (-587.7, 583.8)
#  cp2_2017...w_weekly    57.94    421.5    0.1374    0.891              (-768.7, 884.6)
#  cp3_2018...w_weekly   -121.9    134.6   -0.9055    0.365              (-385.8, 142.1)
#  cp3_2018...w_weekly   -87.73    261.5   -0.3355    0.737              (-600.5, 425.1)
#  cp3_2018...w_weekly    78.92    162.8    0.4849    0.628              (-240.3, 398.1)
#  cp3_2018...w_weekly   -134.5    229.7   -0.5856    0.558              (-584.9, 315.9)
#  cp4_2018...w_weekly   -266.7    237.4    -1.124    0.261              (-732.2, 198.8)
#  cp4_2018...w_weekly    559.9    460.5     1.216    0.224             (-343.1, 1463.0)
#  cp4_2018...w_weekly   -17.18    286.7  -0.05992    0.952              (-579.5, 545.1)
#  cp4_2018...w_weekly    615.4    405.4     1.518    0.129             (-179.6, 1410.0)
#  cp5_2018...w_weekly    405.3    280.7     1.444    0.149              (-145.2, 955.8)
#  cp5_2018...w_weekly   -461.3    544.6   -0.8471    0.397             (-1529.0, 606.6)
#  cp5_2018...w_weekly    -3.38    339.5 -0.009956    0.992              (-669.1, 662.3)
#  cp5_2018...w_weekly   -368.9    479.5   -0.7693    0.442             (-1309.0, 571.5)
#  cp6_2019...w_weekly   -57.39    100.1    -0.573    0.567              (-253.8, 139.0)
#  cp6_2019...w_weekly   -158.1    194.5    -0.813    0.416              (-539.6, 223.3)
#  cp6_2019...w_weekly    34.75    121.4    0.2863    0.775              (-203.3, 272.8)
#  cp6_2019...w_weekly   -209.7    171.2    -1.225    0.221              (-545.4, 126.1)
#  cp7_2019...w_weekly   -57.68    55.31    -1.043    0.297              (-166.2, 50.79)
#  cp7_2019...w_weekly   -56.25    107.3    -0.524    0.600              (-266.8, 154.3)
#  cp7_2019...w_weekly    91.59     67.1     1.365    0.172               (-40.0, 223.2)
#  cp7_2019...w_weekly   -68.95     94.5   -0.7297    0.466              (-254.3, 116.4)
#  cp8_2020...w_weekly    93.12    46.04     2.023    0.043         *     (2.828, 183.4)
#  cp8_2020...w_weekly    32.33    89.29    0.3621    0.717              (-142.8, 207.4)
#  cp8_2020...w_weekly   -29.84    55.68   -0.5358    0.592              (-139.0, 79.37)
#  cp8_2020...w_weekly    129.3    78.53     1.646    0.100         .    (-24.73, 283.3)
#      sin1_tow_weekly     48.2    4.462      10.8   <2e-16       ***     (39.45, 56.95)
#      cos1_tow_weekly    35.28    5.842     6.038 1.84e-09       ***     (23.82, 46.73)
#      sin2_tow_weekly   -4.566    4.484    -1.018    0.309              (-13.36, 4.228)
#      cos2_tow_weekly    5.974    5.814     1.028    0.304              (-5.427, 17.37)
#      sin3_tow_weekly    41.15    3.367     12.22   <2e-16       ***     (34.55, 47.76)
#      cos3_tow_weekly     72.2      5.8     12.45   <2e-16       ***     (60.82, 83.57)
#      sin4_tow_weekly    25.95    3.312     7.837 7.32e-15       ***     (19.46, 32.45)
#   sin4_toq_quarterly   0.6582    3.036    0.2168    0.828              (-5.296, 6.612)
#   cos4_toq_quarterly     4.13    3.098     1.333    0.183               (-1.945, 10.2)
#   sin5_toq_quarterly   0.5209    3.047    0.1709    0.864              (-5.455, 6.497)
#   cos5_toq_quarterly  -0.3961    3.086   -0.1284    0.898              (-6.448, 5.656)
#      sin1_ct1_yearly    81.83    6.157     13.29   <2e-16       ***      (69.75, 93.9)
#      cos1_ct1_yearly    146.4    7.647     19.15   <2e-16       ***     (131.4, 161.4)
#      sin2_ct1_yearly    -36.3    3.413    -10.63   <2e-16       ***    (-42.99, -29.6)
#      cos2_ct1_yearly     39.5     3.13     12.62   <2e-16       ***     (33.36, 45.63)
#      sin3_ct1_yearly    8.152    3.104     2.627    0.009        **     (2.065, 14.24)
#      cos3_ct1_yearly    17.11    3.124     5.478 4.84e-08       ***     (10.99, 23.24)
#      sin4_ct1_yearly   -7.124    3.035    -2.347    0.019         *   (-13.08, -1.172)
#      cos4_ct1_yearly     16.2    3.132     5.172 2.54e-07       ***     (10.06, 22.34)
#      sin5_ct1_yearly   -11.38    3.052     -3.73 1.97e-04       ***   (-17.37, -5.398)
#      cos5_ct1_yearly   -4.658    3.095    -1.505    0.132              (-10.73, 1.412)
#      sin6_ct1_yearly   0.1221    3.039   0.04018    0.968              (-5.838, 6.082)
#      cos6_ct1_yearly   -3.532    3.105    -1.137    0.256              (-9.621, 2.558)
#      sin7_ct1_yearly   -11.93    3.062    -3.897 1.01e-04       ***   (-17.94, -5.928)
#      cos7_ct1_yearly    1.275    3.103    0.4109    0.681              (-4.811, 7.361)
#      sin8_ct1_yearly   -5.995    3.026    -1.981    0.048         *  (-11.93, -0.0609)
#      cos8_ct1_yearly   -8.027    3.148     -2.55    0.011         *    (-14.2, -1.853)
#      sin9_ct1_yearly    4.039    3.031     1.332    0.183              (-1.906, 9.984)
#      cos9_ct1_yearly    0.413    3.101    0.1331    0.894              (-5.669, 6.495)
#     sin10_ct1_yearly   -7.337    3.027    -2.424    0.015         *   (-13.27, -1.401)
#     cos10_ct1_yearly   -7.298    3.089    -2.363    0.018         *   (-13.36, -1.241)
#     sin11_ct1_yearly    12.34    3.025     4.079 4.70e-05       ***     (6.405, 18.27)
#     cos11_ct1_yearly   -6.484    3.089    -2.099    0.036         *  (-12.54, -0.4269)
#     sin12_ct1_yearly  -0.2435    3.044     -0.08    0.936              (-6.214, 5.727)
#     cos12_ct1_yearly   -3.265     3.21    -1.017    0.309              (-9.559, 3.029)
#     sin13_ct1_yearly   0.8379     3.17    0.2643    0.792              (-5.379, 7.055)
#     cos13_ct1_yearly    5.809    3.118     1.863    0.063         .   (-0.3051, 11.92)
#     sin14_ct1_yearly   -5.542    3.125    -1.774    0.076         .   (-11.67, 0.5857)
#     cos14_ct1_yearly    2.189    3.111    0.7036    0.482              (-3.912, 8.289)
#     sin15_ct1_yearly   -1.527    3.049    -0.501    0.616              (-7.507, 4.452)
#     cos15_ct1_yearly     4.56    3.116     1.463    0.144              (-1.552, 10.67)
# Signif. Code: 0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Multiple R-squared: 0.8983,   Adjusted R-squared: 0.8923
# F-statistic: 148.53 on 122 and 2068 DF,   p-value: 1.110e-16
# Model AIC: 34127.0,   model BIC: 34833.0
#
# WARNING: the condition number is large, 3.13e+19. This might indicate that there are strong multicollinearity or other numerical problems.

# %%
# components

from greykite.common.constants import DETAILED_SEASONALITY_COMPONENTS_REGEX_DICT
fig = result.forecast.plot_components(grouping_regex_patterns_dict=DETAILED_SEASONALITY_COMPONENTS_REGEX_DICT)
iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7eadc577-655e-450e-8943-09e63ea0bab3" class="plotly-graph-div" style="height:1050px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7eadc577-655e-450e-8943-09e63ea0bab3")) {                    Plotly.newPlot(                        "7eadc577-655e-450e-8943-09e63ea0bab3",                        [{"line":{"color":"rgb(127, 60, 141)"},"name":"Intercept","opacity":0.8,"x":["2015-01-01T00:00:00","2015-01-02T00:00:00","2015-01-03T00:00:00","2015-01-04T00:00:00","2015-01-05T00:00:00","2015-01-06T00:00:00","2015-01-07T00:00:00","2015-01-08T00:00:00","2015-01-09T00:00:00","2015-01-10T00:00:00","2015-01-11T00:00:00","2015-01-12T00:00:00","2015-01-13T00:00:00","2015-01-14T00:00:00","2015-01-15T00:00:00","2015-01-16T00:00:00","2015-01-17T00:00:00","2015-01-18T00:00:00","2015-01-19T00:00:00","2015-01-20T00:00:00","2015-01-21T00:00:00","2015-01-22T00:00:00","2015-01-23T00:00:00","2015-01-24T00:00:00","2015-01-25T00:00:00","2015-01-26T00:00:00","2015-01-27T00:00:00","2015-01-28T00:00:00","2015-01-29T00:00:00","2015-01-30T00:00:00","2015-01-31T00:00:00","2015-02-01T00:00:00","2015-02-02T00:00:00","2015-02-03T00:00:00","2015-02-04T00:00:00","2015-02-05T00:00:00","2015-02-06T00:00:00","2015-02-07T00:00:00","2015-02-08T00:00:00","2015-02-09T00:00:00","2015-02-10T00:00:00","2015-02-11T00:00:00","2015-02-12T00:00:00","2015-02-13T00:00:00","2015-02-14T00:00:00","2015-02-15T00:00:00","2015-02-16T00:00:00","2015-02-17T00:00:00","2015-02-18T00:00:00","2015-02-19T00:00:00","2015-02-20T00:00:00","2015-02-21T00:00:00","2015-02-22T00:00:00","2015-02-23T00:00:00","2015-02-24T00:00:00","2015-02-25T00:00:00","2015-02-26T00:00:00","2015-02-27T00:00:00","2015-02-28T00:00:00","2015-03-01T00:00:00","2015-03-02T00:00:00","2015-03-03T00:00:00","2015-03-04T00:00:00","2015-03-05T00:00:00","2015-03-06T00:00:00","2015-03-07T00:00:00","2015-03-08T00:00:00","2015-03-09T00:00:00","2015-03-10T00:00:00","2015-03-11T00:00:00","2015-03-12T00:00:00","2015-03-13T00:00:00","2015-03-14T00:00:00","2015-03-15T00:00:00","2015-03-16T00:00:00","2015-03-17T00:00:00","2015-03-18T00:00:00","2015-03-19T00:00:00","2015-03-20T00:00:00","2015-03-21T00:00:00","2015-03-22T00:00:00","2015-03-23T00:00:00","2015-03-24T00:00:00","2015-03-25T00:00:00","2015-03-26T00:00:00","2015-03-27T00:00:00","2015-03-28T00:00:00","2015-03-29T00:00:00","2015-03-30T00:00:00","2015-03-31T00:00:00","2015-04-01T00:00:00","2015-04-02T00:00:00","2015-04-03T00:00:00","2015-04-04T00:00:00","2015-04-05T00:00:00","2015-04-06T00:00:00","2015-04-07T00:00:00","2015-04-08T00:00:00","2015-04-09T00:00:00","2015-04-10T00:00:00","2015-04-11T00:00:00","2015-04-12T00:00:00","2015-04-13T00:00:00","2015-04-14T00:00:00","2015-04-15T00:00:00","2015-04-16T00:00:00","2015-04-17T00:00:00","2015-04-18T00:00:00","2015-04-19T00:00:00","2015-04-20T00:00:00","2015-04-21T00:00:00","2015-04-22T00:00:00","2015-04-23T00:00:00","2015-04-24T00:00:00","2015-04-25T00:00:00","2015-04-26T00:00:00","2015-04-27T00:00:00","2015-04-28T00:00:00","2015-04-29T00:00:00","2015-04-30T00:00:00","2015-05-01T00:00:00","2015-05-02T00:00:00","2015-05-03T00:00:00","2015-05-04T00:00:00","2015-05-05T00:00:00","2015-05-06T00:00:00","2015-05-07T00:00:00","2015-05-08T00:00:00","2015-05-09T00:00:00","2015-05-10T00:00:00","2015-05-11T00:00:00","2015-05-12T00:00:00","2015-05-13T00:00:00","2015-05-14T00:00:00","2015-05-15T00:00:00","2015-05-16T00:00:00","2015-05-17T00:00:00","2015-05-18T00:00:00","2015-05-19T00:00:00","2015-05-20T00:00:00","2015-05-21T00:00:00","2015-05-22T00:00:00","2015-05-23T00:00:00","2015-05-24T00:00:00","2015-05-25T00:00:00","2015-05-26T00:00:00","2015-05-27T00:00:00","2015-05-28T00:00:00","2015-05-29T00:00:00","2015-05-30T00:00:00","2015-05-31T00:00:00","2015-06-01T00:00:00","2015-06-02T00: ...
